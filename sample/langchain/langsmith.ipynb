# %%
# !pip install langchain-teddynote

# %%
from langchain_teddynote import logging

logging.langsmith("default")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# default

# %%
# 추적 끄기
logging.langsmith("default", set_enable=False)
# Out:
# LangSmith 추적을 하지 않습니다.

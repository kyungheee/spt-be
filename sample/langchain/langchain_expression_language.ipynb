# %%
from langchain_teddynote.messages import stream_response # 스트리밍 출력
from langchain_core.prompts import PromptTemplate

template = "{country}의 수도는 어디인가요?"
prompt_template = PromptTemplate.from_template(template)
prompt_template
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
prompt = prompt_template.format(country="대한민국")
prompt
# Out:
# '대한민국의 수도는 어디인가요?'

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
   model = "gpt-4o-mini",
   max_tokens=2048,
   temperature = 0.1
)

# %%
# chain = prompt | model | output_parser
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chain = prompt | model | output_parser
#
# File c:\Users\노경희노경희\OneDrive - 한국능률협회컨설팅\github\spotify-api\spt_env\Lib\site-packages\langchain_core\runnables\base.py:656, in Runnable.__ror__(self, other)
#     637 def __ror__(
#     638     self,
#     639     other: Runnable[Other, Any]
#    (...)    643     | Mapping[str, Runnable[Other, Any] | Callable[[Other], Any] | Any],
#     644 ) -> RunnableSerializable[Other, Output]:
#     645     """Runnable "reverse-or" operator.
#     646
#     647     Compose this `Runnable` with another object to create a
#    (...)    654         A new `Runnable`.
#     655     """
# --> 656     return RunnableSequence(coerce_to_runnable(other), self)
#
# File c:\Users\노경희노경희\OneDrive - 한국능률협회컨설팅\github\spotify-api\spt_env\Lib\site-packages\langchain_core\runnables\base.py:6039, in coerce_to_runnable(thing)
#    6034     return cast("Runnable[Input, Output]", RunnableParallel(thing))
#    6035 msg = (
#    6036     f"Expected a Runnable, callable or dict."
#    6037     f"Instead got an unsupported type: {type(thing)}"
#    6038 )
# -> 6039 raise TypeError(msg)
#
# TypeError: Expected a Runnable, callable or dict.Instead got an unsupported type: <class 'str'>

# %%
prompt = PromptTemplate.from_template("{topic}에 대해 쉽게 설명해주세요")  
model = model

chain = prompt | model

# %%
input = {'topic': '인공지능 모델의 학습 원리'} 

chain.invoke(input)  # prompt 객체와 model 객체를 파이프(|) 연산자로 연결하고 invoke 메서드를 사용하여 input을 전달
# Out:
# AIMessage(content="인공지능 모델의 학습 원리는 크게 두 가지 단계로 나눌 수 있습니다: **훈련(Training)**과 **추론(Inference)**입니다.\n\n1. **훈련(Training)**:\n   - **데이터 수집**: 먼저, 모델이 학습할 데이터를 수집합니다. 이 데이터는 이미지, 텍스트, 소리 등 다양한 형태일 수 있습니다.\n   - **모델 선택**: 학습할 인공지능 모델을 선택합니다. 예를 들어, 이미지 인식에는 CNN(합성곱 신경망)을, 자연어 처리에는 RNN(순환 신경망)이나 Transformer 모델을 사용할 수 있습니다.\n   - **학습 과정**: 모델은 주어진 데이터를 바탕으로 패턴을 학습합니다. 이 과정에서 모델은 입력 데이터와 정답(라벨)을 비교하여 오차를 계산합니다. 이 오차를 줄이기 위해 모델의 내부 파라미터(가중치)를 조정합니다. 이 과정을 여러 번 반복하면서 모델은 점점 더 정확하게 예측할 수 있게 됩니다.\n   - **검증**: 훈련이 끝난 후, 모델의 성능을 평가하기 위해 별도의 검증 데이터를 사용합니다. 이를 통해 모델이 실제 상황에서도 잘 작동하는지 확인합니다.\n\n2. **추론(Inference)**:\n   - 훈련이 완료된 모델은 새로운 데이터를 입력받아 예측을 수행합니다. 이 단계에서는 모델이 학습한 내용을 바탕으로 주어진 입력에 대해 결과를 도출합니다. 예를 들어, 새로운 이미지를 입력받아 그 이미지가 무엇인지 분류하는 작업을 수행합니다.\n\n이러한 과정을 통해 인공지능 모델은 데이터를 이해하고, 예측하며, 다양한 작업을 수행할 수 있게 됩니다. 쉽게 말해, 많은 데이터를 통해 '배우고', 그 배운 내용을 바탕으로 새로운 상황에 '적용'하는 방식이라고 할 수 있습니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 414, 'prompt_tokens': 20, 'total_tokens': 434, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-CiFF8b9cFZN482eHRSLB7g2AhWO9R', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--d5a2fe6a-28f4-43f9-a097-9013a04b5eaa-0', usage_metadata={'input_tokens': 20, 'output_tokens': 414, 'total_tokens': 434, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chain.stream(input)
# Out:
# <generator object RunnableSequence.stream at 0x0000021B931018A0>

# %%
answer = chain.stream(input)
stream_response(answer)
# Out:
# 인공지능 모델의 학습 원리는 크게 두 가지 단계로 나눌 수 있습니다: **훈련(Training)**과 **추론(Inference)**입니다.
#
# 1. **훈련(Training)**:
#    - **데이터 수집**: 먼저, 모델이 학습할 데이터를 수집합니다. 이 데이터는 이미지, 텍스트, 소리 등 다양한 형태일 수 있습니다.
#    - **모델 선택**: 학습할 인공지능 모델의 구조를 선택합니다. 예를 들어, 신경망(Neural Network) 같은 구조를 사용할 수 있습니다.
#    - **학습 과정**: 모델은 주어진 데이터를 바탕으로 패턴을 학습합니다. 이 과정에서 모델은 입력 데이터와 정답(라벨)을 비교하여 오차를 계산합니다. 이 오차를 줄이기 위해 모델의 내부 파라미터(가중치)를 조정합니다. 이 과정을 여러 번 반복하면서 모델은 점점 더 정확하게 예측할 수 있게 됩니다.
#    - **검증(Validation)**: 훈련이 끝난 후, 모델의 성능을 평가하기 위해 별도의 검증 데이터를 사용합니다. 이를 통해 모델이 실제 상황에서도 잘 작동하는지 확인합니다.
#
# 2. **추론(Inference)**:
#    - 훈련이 완료된 모델은 새로운 데이터를 입력받아 예측을 수행합니다. 이 단계에서는 모델이 학습한 내용을 바탕으로 주어진 입력에 대해 결과를 도출합니다.
#
# 이러한 과정을 통해 인공지능 모델은 데이터를 이해하고, 패턴을 인식하며, 예측을 할 수 있는 능력을 갖추게 됩니다. 쉽게 말해, 많은 데이터를 통해 '배우고', 그 배운 내용을 바탕으로 새로운 상황에 대응하는 것입니다.

# %% [markdown]
# ### 출력파서 (Output Parser)

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

chain = prompt | model | output_parser

input = {'topic' : '인공지능 모델의 학습 원리'}
chain.invoke(input)
# Out:
# '인공지능 모델의 학습 원리는 크게 두 가지 단계로 나눌 수 있습니다: **훈련(Training)**과 **추론(Inference)**입니다.\n\n1. **훈련(Training)**:\n   - **데이터 수집**: 먼저, 모델이 학습할 데이터를 수집합니다. 이 데이터는 이미지, 텍스트, 소리 등 다양한 형태일 수 있습니다.\n   - **모델 선택**: 어떤 종류의 인공지능 모델을 사용할지 결정합니다. 예를 들어, 이미지 인식에는 CNN(합성곱 신경망)을, 자연어 처리에는 RNN(순환 신경망)이나 Transformer 모델을 사용할 수 있습니다.\n   - **학습**: 모델은 주어진 데이터를 바탕으로 패턴을 학습합니다. 이 과정에서 모델은 입력 데이터와 정답(레이블) 간의 관계를 이해하려고 합니다. 예를 들어, 고양이와 개의 이미지를 분류하는 모델은 각각의 이미지가 어떤 동물인지 학습합니다.\n   - **오차 계산**: 모델이 예측한 결과와 실제 정답 간의 차이를 계산하여 오차를 구합니다. 이 오차를 줄이기 위해 모델의 내부 파라미터(가중치)를 조정합니다.\n   - **반복**: 이 과정을 여러 번 반복하면서 모델의 성능을 점점 개선해 나갑니다. 이를 통해 모델은 데이터의 패턴을 점점 더 잘 이해하게 됩니다.\n\n2. **추론(Inference)**:\n   - 훈련이 완료된 모델은 새로운 데이터를 입력받아 예측을 수행합니다. 이 단계에서는 모델이 학습한 내용을 바탕으로 주어진 입력에 대해 결과를 도출합니다. 예를 들어, 새로운 이미지를 입력받아 그것이 고양이인지 개인지 판단하는 것입니다.\n\n이러한 과정을 통해 인공지능 모델은 데이터를 분석하고, 예측하며, 다양한 작업을 수행할 수 있게 됩니다. 요약하자면, 인공지능 모델은 많은 데이터를 통해 학습하고, 그 학습한 내용을 바탕으로 새로운 상황에 대응하는 능력을 갖추게 됩니다.'

# %%
answer = chain.stream(input)
stream_response(answer)
# Out:
# 인공지능 모델의 학습 원리는 크게 두 가지 단계로 나눌 수 있습니다: **훈련(Training)**과 **추론(Inference)**입니다.
#
# 1. **훈련(Training)**:
#    - **데이터 수집**: 먼저, 모델이 학습할 데이터를 수집합니다. 이 데이터는 이미지, 텍스트, 소리 등 다양한 형태일 수 있습니다.
#    - **모델 선택**: 학습할 모델의 구조를 선택합니다. 예를 들어, 신경망(Neural Network) 같은 복잡한 구조를 사용할 수 있습니다.
#    - **학습 과정**: 모델은 주어진 데이터를 바탕으로 패턴을 학습합니다. 이 과정에서 모델은 입력 데이터와 정답(라벨)을 비교하여 오차를 계산합니다. 이 오차를 줄이기 위해 모델의 내부 파라미터(가중치)를 조정합니다. 이 과정을 여러 번 반복하면서 모델은 점점 더 정확하게 예측할 수 있게 됩니다.
#    - **검증(Validation)**: 훈련이 끝난 후, 모델의 성능을 평가하기 위해 별도의 검증 데이터를 사용합니다. 이를 통해 모델이 실제 상황에서도 잘 작동하는지 확인합니다.
#
# 2. **추론(Inference)**:
#    - 훈련이 완료된 모델은 새로운 데이터를 입력받아 예측을 수행합니다. 이 단계에서는 모델이 학습한 내용을 바탕으로 입력 데이터에 대한 결과를 생성합니다.
#
# 이러한 과정을 통해 인공지능 모델은 주어진 문제를 해결할 수 있는 능력을 갖추게 됩니다. 쉽게 말해, 많은 데이터를 통해 '배우고', 그 배운 내용을 바탕으로 새로운 상황에 맞게 '예측'하는 것입니다.

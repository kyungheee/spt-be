# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pprint

cid = '8526b8f79057420980beef4c60459906'
secret = '99dc02d36eec46e5b225d5e58b48ad7d'
redirect_uri = 'https://open.spotify.com/'
sp = spotipy.Spotify(auth_manager = SpotifyOAuth(client_id=cid, client_secret=secret, redirect_uri=redirect_uri))

# %%
search_artist = sp.search('iu', limit=3, type = 'artist') 
pprint.pprint(search_artist['artists']['items'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#   'followers': {'href': None, 'total': 9463068},
#   'genres': ['k-pop', 'k-ballad'],
#   'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#   'id': '3HqSLMAZ3g3d5poNaI7GOU',
#   'images': [{'height': 640,
#               'url': 'https://i.scdn.co/image/ab6761610000e5eb789f38042e5ef8911fc3826b',
#               'width': 640},
#              {'height': 320,
#               'url': 'https://i.scdn.co/image/ab67616100005174789f38042e5ef8911fc3826b',
#               'width': 320},
#              {'height': 160,
#               'url': 'https://i.scdn.co/image/ab6761610000f178789f38042e5ef8911fc3826b',
#               'width': 160}],
#   'name': 'IU',
#   'popularity': 68,
#   'type': 'artist',
#   'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
# ...

# %%
uri = '3HqSLMAZ3g3d5poNaI7GOU' # 아티스트 id
artist = sp.artist(uri)
pprint.pprint(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#  'followers': {'href': None, 'total': 9463068},
#  'genres': ['k-pop', 'k-ballad'],
#  'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#  'id': '3HqSLMAZ3g3d5poNaI7GOU',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/ab6761610000e5eb789f38042e5ef8911fc3826b',
#              'width': 640},
#             {'height': 320,
#              'url': 'https://i.scdn.co/image/ab67616100005174789f38042e5ef8911fc3826b',
#              'width': 320},
#             {'height': 160,
#              'url': 'https://i.scdn.co/image/ab6761610000f178789f38042e5ef8911fc3826b',
#              'width': 160}],
#  'name': 'IU',
#  'popularity': 68,
#  'type': 'artist',
#  'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}

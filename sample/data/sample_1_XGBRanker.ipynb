# %%
import pandas as pd

request = pd.read_excel('./sample_data.xlsx', sheet_name="request")
impression = pd.read_excel('./sample_data.xlsx', sheet_name="impression")
feedback = pd.read_excel('./sample_data.xlsx', sheet_name="feedback")

feedback
# Out:
#     request_id track_id  clicked  skipped_10s  listened_30s  liked  \
# 0     REQ_0001  TRK_111        1            0             1      1
# 1     REQ_0001  TRK_005        1            0             1      0
# 2     REQ_0001  TRK_028        1            0             0      0
# 3     REQ_0001  TRK_040        0            0             0      0
# 4     REQ_0001  TRK_041        0            0             0      0
# ..         ...      ...      ...          ...           ...    ...
# 245   REQ_0050  TRK_054        1            0             1      0
# 246   REQ_0050  TRK_001        1            0             0      0
# 247   REQ_0050  TRK_008        1            0             0      0
# 248   REQ_0050  TRK_094        1            0             0      0
# 249   REQ_0050  TRK_006        0            0             0      0
#
#      listened_sec
# 0              30
# 1              31
# 2              10
# 3               0
# 4               0
# ..            ...
# 245           106
# 246            26
# 247            27
# 248            28
# 249             0
#
# [250 rows x 7 columns]

# %%
def validate_feedback(df):
    violations = []
    
    # 1) listened_sec ==0 
    mask = df["listened_sec"] == 0
    v = df[mask & (
        (df["clicked"] != 0) |
        (df["skipped_10s"] != 0) |
        (df["listened_30s"] != 0)
    )]
    if not v.empty:
        violations.append(("listened_sec == 0 rule", v))
        
    # 2) 1 ~ 9
    mask = df["listened_sec"].between(1, 9)
    v = df[mask & (
        (df["clicked"] != 1) |
        (df["skipped_10s"] != 1) |
        (df["listened_30s"] != 0)
    )]
    if not v.empty:
        violations.append(("1 <= listened_sec <= 9 rule", v))

    # 3) 10 ~ 29
    mask = df["listened_sec"].between(10, 29)
    v = df[mask & (
        (df["clicked"] != 1) |
        (df["skipped_10s"] != 0) |
        (df["listened_30s"] != 0)
    )]
    if not v.empty:
        violations.append(("10 <= listened_sec <= 29 rule", v))

    # 4) >= 30
    mask = df["listened_sec"] >= 30
    v = df[mask & (
        (df["clicked"] != 1) |
        (df["skipped_10s"] != 0) |
        (df["listened_30s"] != 1)
    )]
    if not v.empty:
        violations.append(("listened_sec >= 30 rule", v))

    # ---- 결과 출력 ----
    if not violations:
        print("✅ ALL CHECKS PASSED")
    else:
        print("❌ VIOLATIONS FOUND\n")
        for name, rows in violations:
            print(f"[{name}] → {len(rows)} rows")
            print(rows[[
                "request_id",
                "track_id",
                "clicked",
                "skipped_10s",
                "listened_30s",
                "listened_sec"
            ]].head(), "\n")


validate_feedback(feedback)
# Out:
# ✅ ALL CHECKS PASSED

# %%
dups_fb = feedback.duplicated(["request_id","track_id"], keep=False)
print("feedback dup rows:", dups_fb.sum())

feedback.loc[dups_fb].sort_values(["request_id","track_id"]).head(50)
# Out:
# feedback dup rows: 0
# Empty DataFrame
# Columns: [request_id, track_id, clicked, skipped_10s, listened_30s, liked, listened_sec]
# Index: []

# %%
dups_req = request.duplicated(["request_id"], keep=False)
print("request dup rows:", dups_req.sum())

request.loc[dups_req].sort_values(["request_id"]).head(50)
# Out:
# request dup rows: 0
# Empty DataFrame
# Columns: [request_id, user_id, created_at, context_text, mood_vector, dominant_mood, mood_level_max, mood_entropy, situation_tag, place_tag, weather_tag]
# Index: []

# %%
# 학습 단위(track 하나) 테이블 만들기
df = (
    impression
    .merge(feedback, on=["request_id", "track_id"], how="left")
    .merge(request, on="request_id", how="left")
)

df
# Out:
#        policy_id request_id track_id  track_feature1  track_feature2  \
# 0    POL_RULE_V1   REQ_0001  TRK_111           0.735           0.470
# 1    POL_RULE_V1   REQ_0001  TRK_005           0.752           0.504
# 2    POL_RULE_V1   REQ_0001  TRK_028           0.785           0.570
# 3    POL_RULE_V1   REQ_0001  TRK_040           0.741           0.482
# 4    POL_RULE_V1   REQ_0001  TRK_041           0.748           0.496
# ..           ...        ...      ...             ...             ...
# 245  POL_RULE_V2   REQ_0050  TRK_054           0.775           0.550
# 246  POL_RULE_V2   REQ_0050  TRK_001           0.724           0.448
# 247  POL_RULE_V2   REQ_0050  TRK_008           0.773           0.546
# 248  POL_RULE_V2   REQ_0050  TRK_094           0.799           0.598
# 249  POL_RULE_V2   REQ_0050  TRK_006           0.759           0.518
#
#      track_feature3  track_feature4  rank  clicked  skipped_10s  ...  user_id  \
# 0             0.675           0.145     1        1            0  ...    U_001
# 1             0.760           0.264     2        1            0  ...    U_001
# 2             0.925           0.495     3        1            0  ...    U_001
# 3             0.705           0.187     4        0            0  ...    U_001
# 4             0.740           0.236     5        0            0  ...    U_001
# ..              ...             ...   ...      ...          ...  ...      ...
# 245           0.875           0.425     1        1            0  ...    U_001
# 246           0.620           0.068     2        1            0  ...    U_001
# 247           0.865           0.411     3        1            0  ...    U_001
# 248           0.995           0.593     4        1            0  ...    U_001
# 249           0.795           0.313     5        0            0  ...    U_001
#
#              created_at         context_text      mood_vector dominant_mood  \
# 0   2025-01-01 08:12:00  출근 준비하면서 기분이 좀 가라앉아  [1,7,3,4,1,2,1]       sadness
# 1   2025-01-01 08:12:00  출근 준비하면서 기분이 좀 가라앉아  [1,7,3,4,1,2,1]       sadness
# 2   2025-01-01 08:12:00  출근 준비하면서 기분이 좀 가라앉아  [1,7,3,4,1,2,1]       sadness
# 3   2025-01-01 08:12:00  출근 준비하면서 기분이 좀 가라앉아  [1,7,3,4,1,2,1]       sadness
# 4   2025-01-01 08:12:00  출근 준비하면서 기분이 좀 가라앉아  [1,7,3,4,1,2,1]       sadness
# ..                  ...                  ...              ...           ...
# 245 2025-01-23 22:15:00   하루 마무리하면서 차분해지고 싶어  [0,2,0,1,0,2,2]           joy
# 246 2025-01-23 22:15:00   하루 마무리하면서 차분해지고 싶어  [0,2,0,1,0,2,2]           joy
# 247 2025-01-23 22:15:00   하루 마무리하면서 차분해지고 싶어  [0,2,0,1,0,2,2]           joy
# 248 2025-01-23 22:15:00   하루 마무리하면서 차분해지고 싶어  [0,2,0,1,0,2,2]           joy
# 249 2025-01-23 22:15:00   하루 마무리하면서 차분해지고 싶어  [0,2,0,1,0,2,2]           joy
#
#     mood_level_max mood_entropy situation_tag  place_tag  weather_tag
# 0                7         1.42     commuting       home       cloudy
# 1                7         1.42     commuting       home       cloudy
# 2                7         1.42     commuting       home       cloudy
# 3                7         1.42     commuting       home       cloudy
# 4                7         1.42     commuting       home       cloudy
# ..             ...          ...           ...        ...          ...
# 245              2         1.09      sleeping       home        night
# 246              2         1.09      sleeping       home        night
# 247              2         1.09      sleeping       home        night
# 248              2         1.09      sleeping       home        night
# 249              2         1.09      sleeping       home        night
#
# [250 rows x 23 columns]

# %%
df.groupby("rank")["clicked"].mean()
# Out:
# rank
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.5
# 5    0.0
# Name: clicked, dtype: float64

# %%
df["reward_score"] = (
    5 * df["liked"] +
    4 * df["listened_30s"] + 
    2 * df["skipped_10s"]
)

df.groupby("rank")["reward_score"].mean()
# Out:
# rank
# 1    6.44
# 2    2.32
# 3    1.46
# 4    2.60
# 5    0.20
# Name: reward_score, dtype: float64

# %%
import numpy as np
import ast

#Shannon Entropy
def mood_entropy(mood_vector):
    x = np.array(mood_vector, dtype=float)
    if x.sum() == 0:
        return 0.0
    p = x / x.sum()
    p = p[p>0]
    return -np.sum(p*np.log(p))

df["mood_vector_parsed"] = df["mood_vector"].apply(ast.literal_eval) 
df["mood_entropy"] = df["mood_vector_parsed"].apply(mood_entropy)

df["mood_entropy"]
# Out:
# 0      1.689245
# 1      1.689245
# 2      1.689245
# 3      1.689245
# 4      1.689245
#          ...
# 245    1.351784
# 246    1.351784
# 247    1.351784
# 248    1.351784
# 249    1.351784
# Name: mood_entropy, Length: 250, dtype: float64

# %%
df.to_excel("./sample_data_1.xlsx")

# %%
df.columns
# Out:
# Index(['policy_id', 'request_id', 'track_id', 'track_feature1',
#        'track_feature2', 'track_feature3', 'track_feature4', 'rank', 'clicked',
#        'skipped_10s', 'listened_30s', 'liked', 'listened_sec', 'user_id',
#        'created_at', 'context_text', 'mood_vector', 'dominant_mood',
#        'mood_level_max', 'mood_entropy', 'situation_tag', 'place_tag',
#        'weather_tag', 'reward_score', 'mood_vector_parsed'],
#       dtype='object')

# %%
mood_cols = ["anger","sadness","pain","anxiety","shame","joy","love"]

mood_df = pd.DataFrame(df["mood_vector_parsed"].tolist(),
                       columns=[f"mood_{c}" for c in mood_cols])

mood_df
# Out:
#      mood_anger  mood_sadness  mood_pain  mood_anxiety  mood_shame  mood_joy  \
# 0             1             7          3             4           1         2
# 1             1             7          3             4           1         2
# 2             1             7          3             4           1         2
# 3             1             7          3             4           1         2
# 4             1             7          3             4           1         2
# ..          ...           ...        ...           ...         ...       ...
# 245           0             2          0             1           0         2
# 246           0             2          0             1           0         2
# 247           0             2          0             1           0         2
# 248           0             2          0             1           0         2
# 249           0             2          0             1           0         2
#
#      mood_love
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 245          2
# 246          2
# 247          2
# 248          2
# 249          2
#
# [250 rows x 7 columns]

# %%
dominant_mood = pd.get_dummies(df["dominant_mood"], 
                               columns=["dominant_mood"], 
                               prefix="dominant_mood")

situation_tag = pd.get_dummies(df["situation_tag"],
                               columns=["situation_tag"],
                               prefix="situation")

place_tag = pd.get_dummies(df["place_tag"],
                           columns=["place_tag"],
                           prefix="place")

weather_tag = pd.get_dummies(df["weather_tag"],
                             columns=["weather_tag"],
                             prefix="weather")

weather_tag
# Out:
#      weather_clear  weather_cloudy  weather_night  weather_rain
# 0            False            True          False         False
# 1            False            True          False         False
# 2            False            True          False         False
# 3            False            True          False         False
# 4            False            True          False         False
# ..             ...             ...            ...           ...
# 245          False           False           True         False
# 246          False           False           True         False
# 247          False           False           True         False
# 248          False           False           True         False
# 249          False           False           True         False
#
# [250 rows x 4 columns]

# %%
X = pd.concat([mood_df, dominant_mood, df["mood_level_max"], df["mood_entropy"],
                situation_tag, place_tag, weather_tag,
                df["track_feature1"],df["track_feature2"], df["track_feature3"], df["track_feature4"],
                df["rank"]], axis=1).astype(float)

X
# Out:
#      mood_anger  mood_sadness  mood_pain  mood_anxiety  mood_shame  mood_joy  \
# 0             1             7          3             4           1         2
# 1             1             7          3             4           1         2
# 2             1             7          3             4           1         2
# 3             1             7          3             4           1         2
# 4             1             7          3             4           1         2
# ..          ...           ...        ...           ...         ...       ...
# 245           0             2          0             1           0         2
# 246           0             2          0             1           0         2
# 247           0             2          0             1           0         2
# 248           0             2          0             1           0         2
# 249           0             2          0             1           0         2
#
#      mood_love  dominant_mood_anxiety  dominant_mood_joy  dominant_mood_love  \
# 0            1                  False              False               False
# 1            1                  False              False               False
# 2            1                  False              False               False
# 3            1                  False              False               False
# 4            1                  False              False               False
# ..         ...                    ...                ...                 ...
# 245          2                  False               True               False
# 246          2                  False               True               False
# 247          2                  False               True               False
# 248          2                  False               True               False
# 249          2                  False               True               False
#
#      ...  place_transport  weather_clear  weather_cloudy  weather_night  \
# 0    ...            False          False            True          False
# 1    ...            False          False            True          False
# 2    ...            False          False            True          False
# 3    ...            False          False            True          False
# 4    ...            False          False            True          False
# ..   ...              ...            ...             ...            ...
# 245  ...            False          False           False           True
# 246  ...            False          False           False           True
# 247  ...            False          False           False           True
# 248  ...            False          False           False           True
# 249  ...            False          False           False           True
#
#      weather_rain  track_feature1  track_feature2  track_feature3  \
# 0           False           0.735           0.470           0.675
# 1           False           0.752           0.504           0.760
# 2           False           0.785           0.570           0.925
# 3           False           0.741           0.482           0.705
# 4           False           0.748           0.496           0.740
# ..            ...             ...             ...             ...
# 245         False           0.775           0.550           0.875
# 246         False           0.724           0.448           0.620
# 247         False           0.773           0.546           0.865
# 248         False           0.799           0.598           0.995
# 249         False           0.759           0.518           0.795
#
#      track_feature4  rank
# 0             0.145     1
# 1             0.264     2
# 2             0.495     3
# 3             0.187     4
# 4             0.236     5
# ..              ...   ...
# 245           0.425     1
# 246           0.068     2
# 247           0.411     3
# 248           0.593     4
# 249           0.313     5
#
# [250 rows x 37 columns]

# %%
y = df["reward_score"].astype(float)

y
# Out:
# 0      9.0
# 1      4.0
# 2      0.0
# 3      0.0
# 4      0.0
#       ...
# 245    4.0
# 246    0.0
# 247    0.0
# 248    0.0
# 249    0.0
# Name: reward_score, Length: 250, dtype: float64

# %%
sort_cols = ["request_id", "rank"]

df = df.sort_values(sort_cols).reset_index(drop=True)
X = X.loc[df.index].reset_index(drop=True)
y = y.loc[df.index].reset_index(drop=True)

y
# Out:
# 0      9.0
# 1      4.0
# 2      0.0
# 3      0.0
# 4      0.0
#       ...
# 245    4.0
# 246    0.0
# 247    0.0
# 248    0.0
# 249    0.0
# Name: reward_score, Length: 250, dtype: float64

# %%
req_ids = df["request_id"].unique()
rng = np.random.default_rng(33) 
rng.shuffle(req_ids)

# %%
n_train = int(len(req_ids)*0.8) 
train_reqs = set(req_ids[:n_train])
test_reqs = set(req_ids[n_train:])

train_mask = df["request_id"].isin(train_reqs)
test_mask = df["request_id"].isin(test_reqs)

X_train, y_train = X[train_mask], y[train_mask]
X_test, y_test = X[test_mask], y[test_mask]

df_test = df[test_mask].copy()

df_test
# Out:
#          policy_id request_id track_id  track_feature1  track_feature2  \
# 25   POL_HYBRID_V1   REQ_0006  TRK_111           0.735           0.470
# 26   POL_HYBRID_V1   REQ_0006  TRK_117           0.777           0.554
# 27   POL_HYBRID_V1   REQ_0006  TRK_120           0.734           0.468
# 28   POL_HYBRID_V1   REQ_0006  TRK_046           0.783           0.566
# 29   POL_HYBRID_V1   REQ_0006  TRK_083           0.786           0.572
# 35     POL_RULE_V2   REQ_0008  TRK_016           0.765           0.530
# 36     POL_RULE_V2   REQ_0008  TRK_049           0.804           0.608
# 37     POL_RULE_V2   REQ_0008  TRK_007           0.766           0.532
# 38     POL_RULE_V2   REQ_0008  TRK_080           0.765           0.530
# 39     POL_RULE_V2   REQ_0008  TRK_119           0.791           0.582
# 60     POL_RULE_V1   REQ_0013  TRK_008           0.773           0.546
# 61     POL_RULE_V1   REQ_0013  TRK_082           0.779           0.558
# 62     POL_RULE_V1   REQ_0013  TRK_143           0.767           0.534
# 63     POL_RULE_V1   REQ_0013  TRK_096           0.813           0.626
# 64     POL_RULE_V1   REQ_0013  TRK_079           0.822           0.644
# 65     POL_RULE_V2   REQ_0014  TRK_116           0.770           0.540
# 66     POL_RULE_V2   REQ_0014  TRK_044           0.769           0.538
# 67     POL_RULE_V2   REQ_0014  TRK_058           0.803           0.606
# 68     POL_RULE_V2   REQ_0014  TRK_096           0.813           0.626
# 69     POL_RULE_V2   REQ_0014  TRK_063           0.774           0.548
# 90     POL_RULE_V1   REQ_0019  TRK_140           0.746           0.492
# 91     POL_RULE_V1   REQ_0019  TRK_035           0.770           0.540
# 92     POL_RULE_V1   REQ_0019  TRK_007           0.766           0.532
# 93     POL_RULE_V1   REQ_0019  TRK_049           0.804           0.608
# 94     POL_RULE_V1   REQ_0019  TRK_020           0.729           0.458
# 95     POL_RULE_V2   REQ_0020  TRK_008           0.773           0.546
# 96     POL_RULE_V2   REQ_0020  TRK_002           0.731           0.462
# 97     POL_RULE_V2   REQ_0020  TRK_114           0.756           0.512
# 98     POL_RULE_V2   REQ_0020  TRK_108           0.778           0.556
# 99     POL_RULE_V2   REQ_0020  TRK_140           0.746           0.492
# 100  POL_HYBRID_V1   REQ_0021  TRK_079           0.822           0.644
# 101  POL_HYBRID_V1   REQ_0021  TRK_036           0.777           0.554
# 102  POL_HYBRID_V1   REQ_0021  TRK_088           0.821           0.642
# 103  POL_HYBRID_V1   REQ_0021  TRK_053           0.768           0.536
# 104  POL_HYBRID_V1   REQ_0021  TRK_120           0.734           0.468
# 115  POL_HYBRID_V1   REQ_0024  TRK_039           0.798           0.596
# 116  POL_HYBRID_V1   REQ_0024  TRK_119           0.791           0.582
# 117  POL_HYBRID_V1   REQ_0024  TRK_047           0.790           0.580
# 118  POL_HYBRID_V1   REQ_0024  TRK_103           0.743           0.486
# 119  POL_HYBRID_V1   REQ_0024  TRK_101           0.729           0.458
# 170    POL_RULE_V2   REQ_0035  TRK_095           0.806           0.612
# 171    POL_RULE_V2   REQ_0035  TRK_094           0.799           0.598
# 172    POL_RULE_V2   REQ_0035  TRK_006           0.759           0.518
# 173    POL_RULE_V2   REQ_0035  TRK_137           0.789           0.578
# 174    POL_RULE_V2   REQ_0035  TRK_100           0.722           0.444
# 235  POL_HYBRID_V1   REQ_0048  TRK_122           0.748           0.496
# 236  POL_HYBRID_V1   REQ_0048  TRK_120           0.734           0.468
# 237  POL_HYBRID_V1   REQ_0048  TRK_034           0.763           0.526
# 238  POL_HYBRID_V1   REQ_0048  TRK_117           0.777           0.554
# 239  POL_HYBRID_V1   REQ_0048  TRK_128           0.790           0.580
#
#      track_feature3  track_feature4  rank  clicked  skipped_10s  ...  \
# 25            0.675           0.145     1        1            0  ...
# 26            0.885           0.439     2        1            0  ...
# 27            0.670           0.138     3        1            0  ...
# 28            0.915           0.481     4        0            0  ...
# 29            0.930           0.502     5        0            0  ...
# 35            0.825           0.355     1        1            0  ...
# 36            0.020           0.628     2        1            0  ...
# 37            0.830           0.362     3        1            0  ...
# 38            0.825           0.355     4        0            0  ...
# 39            0.955           0.537     5        0            0  ...
# 60            0.865           0.411     1        1            0  ...
# 61            0.895           0.453     2        1            0  ...
# 62            0.835           0.369     3        1            1  ...
# 63            0.065           0.691     4        0            0  ...
# 64            0.110           0.754     5        0            0  ...
# 65            0.850           0.390     1        1            0  ...
# 66            0.845           0.383     2        1            0  ...
# 67            0.015           0.621     3        1            0  ...
# 68            0.065           0.691     4        0            0  ...
# 69            0.870           0.418     5        0            0  ...
# 90            0.730           0.222     1        1            0  ...
# 91            0.850           0.390     2        1            0  ...
# 92            0.830           0.362     3        1            1  ...
# 93            0.020           0.628     4        0            0  ...
# 94            0.645           0.103     5        0            0  ...
# 95            0.865           0.411     1        1            0  ...
# 96            0.655           0.117     2        1            0  ...
# 97            0.780           0.292     3        1            1  ...
# 98            0.890           0.446     4        0            0  ...
# 99            0.730           0.222     5        0            0  ...
# 100           0.110           0.754     1        1            0  ...
# 101           0.885           0.439     2        1            0  ...
# 102           0.105           0.747     3        1            0  ...
# 103           0.840           0.376     4        0            0  ...
# 104           0.670           0.138     5        0            0  ...
# 115           0.990           0.586     1        1            0  ...
# 116           0.955           0.537     2        1            0  ...
# 117           0.950           0.530     3        1            0  ...
# 118           0.715           0.201     4        0            0  ...
# 119           0.645           0.103     5        0            0  ...
# 170           0.030           0.642     1        1            0  ...
# 171           0.995           0.593     2        1            0  ...
# 172           0.795           0.313     3        1            0  ...
# 173           0.945           0.523     4        1            1  ...
# 174           0.610           0.054     5        0            0  ...
# 235           0.740           0.236     1        1            0  ...
# 236           0.670           0.138     2        1            0  ...
# 237           0.815           0.341     3        1            0  ...
# 238           0.885           0.439     4        1            0  ...
# 239           0.950           0.530     5        0            0  ...
#
#          context_text      mood_vector  dominant_mood mood_level_max  \
# 25     상쾌한 아침이야 기분 좋아  [0,0,0,1,0,8,4]            joy              8
# 26     상쾌한 아침이야 기분 좋아  [0,0,0,1,0,8,4]            joy              8
# 27     상쾌한 아침이야 기분 좋아  [0,0,0,1,0,8,4]            joy              8
# 28     상쾌한 아침이야 기분 좋아  [0,0,0,1,0,8,4]            joy              8
# 29     상쾌한 아침이야 기분 좋아  [0,0,0,1,0,8,4]            joy              8
# 35   카페에서 집중해서 공부 중이야  [0,1,1,2,0,3,1]            joy              3
# 36   카페에서 집중해서 공부 중이야  [0,1,1,2,0,3,1]            joy              3
# 37   카페에서 집중해서 공부 중이야  [0,1,1,2,0,3,1]            joy              3
# 38   카페에서 집중해서 공부 중이야  [0,1,1,2,0,3,1]            joy              3
# 39   카페에서 집중해서 공부 중이야  [0,1,1,2,0,3,1]            joy              3
# 60    비 오는 날 혼자 걷고 있어  [0,4,1,2,1,2,3]        sadness              4
# 61    비 오는 날 혼자 걷고 있어  [0,4,1,2,1,2,3]        sadness              4
# 62    비 오는 날 혼자 걷고 있어  [0,4,1,2,1,2,3]        sadness              4
# 63    비 오는 날 혼자 걷고 있어  [0,4,1,2,1,2,3]        sadness              4
# 64    비 오는 날 혼자 걷고 있어  [0,4,1,2,1,2,3]        sadness              4
# 65      오늘 하루 너무 힘들었어  [2,5,4,3,2,0,1]        sadness              5
# 66      오늘 하루 너무 힘들었어  [2,5,4,3,2,0,1]        sadness              5
# 67      오늘 하루 너무 힘들었어  [2,5,4,3,2,0,1]        sadness              5
# 68      오늘 하루 너무 힘들었어  [2,5,4,3,2,0,1]        sadness              5
# 69      오늘 하루 너무 힘들었어  [2,5,4,3,2,0,1]        sadness              5
# 90   요즘 좀 불안하고 생각이 많아  [0,3,1,6,1,1,1]        anxiety              6
# 91   요즘 좀 불안하고 생각이 많아  [0,3,1,6,1,1,1]        anxiety              6
# 92   요즘 좀 불안하고 생각이 많아  [0,3,1,6,1,1,1]        anxiety              6
# 93   요즘 좀 불안하고 생각이 많아  [0,3,1,6,1,1,1]        anxiety              6
# 94   요즘 좀 불안하고 생각이 많아  [0,3,1,6,1,1,1]        anxiety              6
# 95    잠들기 전에 듣기 좋은 노래  [0,2,0,1,0,2,2]            joy              2
# 96    잠들기 전에 듣기 좋은 노래  [0,2,0,1,0,2,2]            joy              2
# 97    잠들기 전에 듣기 좋은 노래  [0,2,0,1,0,2,2]            joy              2
# 98    잠들기 전에 듣기 좋은 노래  [0,2,0,1,0,2,2]            joy              2
# 99    잠들기 전에 듣기 좋은 노래  [0,2,0,1,0,2,2]            joy              2
# 100      혼자 작업하다가 지쳤어  [1,4,2,3,1,1,1]        sadness              4
# 101      혼자 작업하다가 지쳤어  [1,4,2,3,1,1,1]        sadness              4
# 102      혼자 작업하다가 지쳤어  [1,4,2,3,1,1,1]        sadness              4
# 103      혼자 작업하다가 지쳤어  [1,4,2,3,1,1,1]        sadness              4
# 104      혼자 작업하다가 지쳤어  [1,4,2,3,1,1,1]        sadness              4
# 115      괜히 울적해지는 밤이야  [0,5,2,3,2,0,1]        sadness              5
# 116      괜히 울적해지는 밤이야  [0,5,2,3,2,0,1]        sadness              5
# 117      괜히 울적해지는 밤이야  [0,5,2,3,2,0,1]        sadness              5
# 118      괜히 울적해지는 밤이야  [0,5,2,3,2,0,1]        sadness              5
# 119      괜히 울적해지는 밤이야  [0,5,2,3,2,0,1]        sadness              5
# 170       하루 종일 기운 빠져  [1,4,2,2,1,0,0]        sadness              4
# 171       하루 종일 기운 빠져  [1,4,2,2,1,0,0]        sadness              4
# 172       하루 종일 기운 빠져  [1,4,2,2,1,0,0]        sadness              4
# 173       하루 종일 기운 빠져  [1,4,2,2,1,0,0]        sadness              4
# 174       하루 종일 기운 빠져  [1,4,2,2,1,0,0]        sadness              4
# 235   비 오는 날 혼자 듣고 싶어  [0,4,1,2,1,1,2]        sadness              4
# 236   비 오는 날 혼자 듣고 싶어  [0,4,1,2,1,1,2]        sadness              4
# 237   비 오는 날 혼자 듣고 싶어  [0,4,1,2,1,1,2]        sadness              4
# 238   비 오는 날 혼자 듣고 싶어  [0,4,1,2,1,1,2]        sadness              4
# 239   비 오는 날 혼자 듣고 싶어  [0,4,1,2,1,1,2]        sadness              4
#
#     mood_entropy situation_tag place_tag weather_tag  reward_score  \
# 25      0.858741       morning      home       clear             9
# 26      0.858741       morning      home       clear             4
# 27      0.858741       morning      home       clear             0
# 28      0.858741       morning      home       clear             0
# 29      0.858741       morning      home       clear             0
# 35      1.494175      studying      cafe       clear             9
# 36      1.494175      studying      cafe       clear             4
# 37      1.494175      studying      cafe       clear             0
# 38      1.494175      studying      cafe       clear             0
# 39      1.494175      studying      cafe       clear             0
# 60      1.671595       walking   outdoor        rain             4
# 61      1.671595       walking   outdoor        rain             0
# 62      1.671595       walking   outdoor        rain             2
# 63      1.671595       walking   outdoor        rain             0
# 64      1.671595       walking   outdoor        rain             0
# 65      1.676696    after_work      home      cloudy             9
# 66      1.676696    after_work      home      cloudy             4
# 67      1.676696    after_work      home      cloudy             0
# 68      1.676696    after_work      home      cloudy             0
# 69      1.676696    after_work      home      cloudy             0
# 90      1.484458       resting      home       night             4
# 91      1.484458       resting      home       night             0
# 92      1.484458       resting      home       night             2
# 93      1.484458       resting      home       night             5
# 94      1.484458       resting      home       night             0
# 95      1.351784      sleeping      home       night             4
# 96      1.351784      sleeping      home       night             0
# 97      1.351784      sleeping      home       night             2
# 98      1.351784      sleeping      home       night             0
# 99      1.351784      sleeping      home       night             0
# 100     1.778233       working    office      cloudy             9
# 101     1.778233       working    office      cloudy             4
# 102     1.778233       working    office      cloudy             0
# 103     1.778233       working    office      cloudy             0
# 104     1.778233       working    office      cloudy             0
# 115     1.479133       resting      home       night             0
# 116     1.479133       resting      home       night             4
# 117     1.479133       resting      home       night             0
# 118     1.479133       resting      home       night             0
# 119     1.479133       resting      home       night             0
# 170     1.470808    after_work      home      cloudy             9
# 171     1.470808    after_work      home      cloudy             4
# 172     1.470808    after_work      home      cloudy             0
# 173     1.470808    after_work      home      cloudy             7
# 174     1.470808    after_work      home      cloudy             0
# 235     1.641735       resting      home        rain             4
# 236     1.641735       resting      home        rain             0
# 237     1.641735       resting      home        rain             0
# 238     1.641735       resting      home        rain             0
# 239     1.641735       resting      home        rain             0
#
#         mood_vector_parsed
# 25   [0, 0, 0, 1, 0, 8, 4]
# 26   [0, 0, 0, 1, 0, 8, 4]
# 27   [0, 0, 0, 1, 0, 8, 4]
# 28   [0, 0, 0, 1, 0, 8, 4]
# 29   [0, 0, 0, 1, 0, 8, 4]
# 35   [0, 1, 1, 2, 0, 3, 1]
# 36   [0, 1, 1, 2, 0, 3, 1]
# 37   [0, 1, 1, 2, 0, 3, 1]
# 38   [0, 1, 1, 2, 0, 3, 1]
# 39   [0, 1, 1, 2, 0, 3, 1]
# 60   [0, 4, 1, 2, 1, 2, 3]
# 61   [0, 4, 1, 2, 1, 2, 3]
# 62   [0, 4, 1, 2, 1, 2, 3]
# 63   [0, 4, 1, 2, 1, 2, 3]
# 64   [0, 4, 1, 2, 1, 2, 3]
# 65   [2, 5, 4, 3, 2, 0, 1]
# 66   [2, 5, 4, 3, 2, 0, 1]
# 67   [2, 5, 4, 3, 2, 0, 1]
# 68   [2, 5, 4, 3, 2, 0, 1]
# 69   [2, 5, 4, 3, 2, 0, 1]
# 90   [0, 3, 1, 6, 1, 1, 1]
# 91   [0, 3, 1, 6, 1, 1, 1]
# 92   [0, 3, 1, 6, 1, 1, 1]
# 93   [0, 3, 1, 6, 1, 1, 1]
# 94   [0, 3, 1, 6, 1, 1, 1]
# 95   [0, 2, 0, 1, 0, 2, 2]
# 96   [0, 2, 0, 1, 0, 2, 2]
# 97   [0, 2, 0, 1, 0, 2, 2]
# 98   [0, 2, 0, 1, 0, 2, 2]
# 99   [0, 2, 0, 1, 0, 2, 2]
# 100  [1, 4, 2, 3, 1, 1, 1]
# 101  [1, 4, 2, 3, 1, 1, 1]
# 102  [1, 4, 2, 3, 1, 1, 1]
# 103  [1, 4, 2, 3, 1, 1, 1]
# 104  [1, 4, 2, 3, 1, 1, 1]
# 115  [0, 5, 2, 3, 2, 0, 1]
# 116  [0, 5, 2, 3, 2, 0, 1]
# 117  [0, 5, 2, 3, 2, 0, 1]
# 118  [0, 5, 2, 3, 2, 0, 1]
# 119  [0, 5, 2, 3, 2, 0, 1]
# 170  [1, 4, 2, 2, 1, 0, 0]
# 171  [1, 4, 2, 2, 1, 0, 0]
# 172  [1, 4, 2, 2, 1, 0, 0]
# 173  [1, 4, 2, 2, 1, 0, 0]
# 174  [1, 4, 2, 2, 1, 0, 0]
# 235  [0, 4, 1, 2, 1, 1, 2]
# 236  [0, 4, 1, 2, 1, 1, 2]
# 237  [0, 4, 1, 2, 1, 1, 2]
# 238  [0, 4, 1, 2, 1, 1, 2]
# 239  [0, 4, 1, 2, 1, 1, 2]
#
# [50 rows x 25 columns]

# %%
group_train = df.loc[train_mask].groupby("request_id").size().to_list()
group_test = df.loc[test_mask].groupby("request_id").size().to_list()

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\노경희노경희\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\노경희노경희\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\노경희노경희\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from xgboost) (1.16.3)

# %%
from xgboost import XGBRanker

model = XGBRanker(
    objective="rank:ndcg",
    eval_metric="ndcg",
    n_estimators=200,
    learning_rate=0.05,
    max_depth=5,
    subsample=0.9,
    colsample_bytree=0.9,
    random_state=42,
)

model.fit(
    X_train, y_train,
    group=group_train,
    eval_set=[(X_test, y_test)],
    eval_group=[group_test],
    verbose=False
)
# Out:
# XGBRanker(base_score=None, booster=None, callbacks=None, colsample_bylevel=None,
#           colsample_bynode=None, colsample_bytree=0.9, device=None,
#           early_stopping_rounds=None, enable_categorical=False,
#           eval_metric='ndcg', feature_types=None, feature_weights=None,
#           gamma=None, grow_policy=None, importance_type=None,
#           interaction_constraints=None, learning_rate=0.05, max_bin=None,
#           max_cat_threshold=None, max_cat_to_onehot=None, max_delta_step=None,
#           max_depth=5, max_leaves=None, min_child_weight=None, missing=nan,
#           monotone_constraints=None, multi_strategy=None, n_estimators=200,
#           n_jobs=None, num_parallel_tree=None, ...)

# %%
df_test["pred_score"] = model.predict(X_test)

topk = (
    df_test.sort_values(["request_id", "pred_score"], ascending=[True, False])
            .groupby("request_id")
            .head(5)[["request_id", "track_id", "pred_score", "reward_score", "rank"]]
)

topk
# Out:
#     request_id track_id  pred_score  reward_score  rank
# 25    REQ_0006  TRK_111    0.981652             9     1
# 28    REQ_0006  TRK_046    0.000031             0     4
# 29    REQ_0006  TRK_083   -0.928698             0     5
# 26    REQ_0006  TRK_117   -1.261941             4     2
# 27    REQ_0006  TRK_120   -1.799019             0     3
# 35    REQ_0008  TRK_016    1.973619             9     1
# 36    REQ_0008  TRK_049   -0.570204             4     2
# 37    REQ_0008  TRK_007   -0.698977             0     3
# 38    REQ_0008  TRK_080   -0.855281             0     4
# 39    REQ_0008  TRK_119   -2.041661             0     5
# 60    REQ_0013  TRK_008    1.388111             4     1
# 63    REQ_0013  TRK_096    0.404805             0     4
# 62    REQ_0013  TRK_143   -0.686009             2     3
# 64    REQ_0013  TRK_079   -0.775681             0     5
# 61    REQ_0013  TRK_082   -1.439819             0     2
# 65    REQ_0014  TRK_116    1.620816             9     1
# 67    REQ_0014  TRK_058    0.493311             0     3
# 68    REQ_0014  TRK_096    0.040643             0     4
# 66    REQ_0014  TRK_044   -0.966126             4     2
# 69    REQ_0014  TRK_063   -1.818210             0     5
# 90    REQ_0019  TRK_140    1.820688             4     1
# 93    REQ_0019  TRK_049    0.571762             5     4
# 92    REQ_0019  TRK_007   -0.308490             2     3
# 91    REQ_0019  TRK_035   -0.685685             0     2
# 94    REQ_0019  TRK_020   -2.466135             0     5
# 95    REQ_0020  TRK_008    2.199976             4     1
# 97    REQ_0020  TRK_114    0.575817             2     3
# 98    REQ_0020  TRK_108    0.229496             0     4
# 96    REQ_0020  TRK_002   -1.974503             0     2
# 99    REQ_0020  TRK_140   -2.030752             0     5
# 102   REQ_0021  TRK_088    0.230455             0     3
# 100   REQ_0021  TRK_079    0.124550             9     1
# 103   REQ_0021  TRK_053   -1.139501             0     4
# 101   REQ_0021  TRK_036   -1.176153             4     2
# 104   REQ_0021  TRK_120   -2.492795             0     5
# 115   REQ_0024  TRK_039    0.933750             0     1
# 118   REQ_0024  TRK_103   -0.876005             0     4
# 117   REQ_0024  TRK_047   -0.996036             0     3
# 116   REQ_0024  TRK_119   -1.923753             4     2
# 119   REQ_0024  TRK_101   -2.583623             0     5
# 170   REQ_0035  TRK_095    1.188608             9     1
# 172   REQ_0035  TRK_006   -0.309403             0     3
# 173   REQ_0035  TRK_137   -1.285663             7     4
# 171   REQ_0035  TRK_094   -1.696626             4     2
# 174   REQ_0035  TRK_100   -2.424922             0     5
# 235   REQ_0048  TRK_122    1.224511             4     1
# 237   REQ_0048  TRK_034    0.357188             0     3
# 238   REQ_0048  TRK_117    0.106247             0     4
# 236   REQ_0048  TRK_120   -1.350980             0     2
# 239   REQ_0048  TRK_128   -2.165742             0     5

# %%
# 모델이 추천한 상위 K곡을 사용자에게 보여줬을 때, 요청 하나당 얻는 총 만족도의 평균
def mean_reward(df, score_col="pred_score", k=3):
    return (
        df.sort_values(["request_id", score_col], ascending=[True, False])
            .groupby("request_id")
            .head(k)
            .groupby("request_id")["reward_score"]
            .sum()
            .mean()
    )

def metric(df, col, score_col="pred_score", k=3):
    return (
        df.sort_values(["request_id", score_col], ascending=[True, False])
            .groupby("request_id")
            .head(k)[col]
            .mean()
    )
    
for k in range(5,0,-1):
    print("K=", k,
          "original reward@", mean_reward(df_test, "rank", k),
          "reward@", mean_reward(df_test, "pred_score", k),
          "click@", metric(df_test, "clicked", "pred_score", k), # 평균적으로 얼마나 클릭하는지
          "like@", metric(df_test, "liked", "pred_score", k) # 평균적으로 얼마나 좋아요 표시하는지
    )
# Out:
# K= 5 original reward@ 10.3 reward@ 10.3 click@ 0.64 like@ 0.14
# K= 4 original reward@ 4.2 reward@ 10.3 click@ 0.75 like@ 0.175
# K= 3 original reward@ 1.8 reward@ 8.3 click@ 0.7333333333333333 like@ 0.23333333333333334
# K= 2 original reward@ 1.2 reward@ 7.2 click@ 0.8 like@ 0.3
# K= 1 original reward@ 0.0 reward@ 5.2 click@ 1.0 like@ 0.4

# %% [markdown]
# 5위까지 순위를 가진 데이터로 모델을 학습시킨 결과
# - 5위까지 순위 예측: 모델 성능 6.9, 원래 성능 6.9
# - 4위까지 순위 예측: 모델 성능 6.9, 원래 성능 2.8
# - 3위까지 순위 예측: 모델 성능 6.7, 원래 성능 1.4 (점점 떨어짐)
# - 2위까지 순위 예측: 모델 성능 5.3, 원래 성능 0.8
# - 1위까지 순위 예측: 모델 성능 3.9, 원래 성능 0.0 (예측할 수 없음?)
#
# 원래 데이터가지고는 3,4위까지 예측하는 것은 무리가 있음
# 이런 경우엔 모델이 기존 노출 순서보다 더 나은 추천을 함

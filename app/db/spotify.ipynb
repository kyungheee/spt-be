# %%
from get_tracks import *

track_2025= get_tracks_by_year(2025)

track_2025.head(10)
# Out:
#               track_name                track_id  \
# 0  Don’t Say You Love Me  27xkOIER6uDLKALIelHylZ
# 1       NOT CUTE ANYMORE  1k0JAiH11gHL9dc5dfQjQr
# 2               IRIS OUT  59hVbgr8rfYkDbHfr8RcGI
# 3                  FOCUS  6jYiHr12NVKLzn0X7K8aSK
# 4          ONE MORE TIME  4eCan7Jb3q0xQ1FAELOtEz
# 5               JANE DOE  4oE7MyJhqSD3BaHRpNs8Nl
# 6         Blue Valentine  0FKR7mQJnYqdEmHAMhgQjw
# 7                ULSSIGU  651GMkAaR0JbpzZXRvdQ3D
# 8         Eternal Moment  2aSfmbpproCPOe2j01WT2a
# 9                    0+0  3sOAwRg5esaxDcWnUigWPv
#
#                               track_uri      artist_name  \
# 0  spotify:track:27xkOIER6uDLKALIelHylZ              Jin
# 1  spotify:track:1k0JAiH11gHL9dc5dfQjQr            ILLIT
# 2  spotify:track:59hVbgr8rfYkDbHfr8RcGI    Kenshi Yonezu
# 3  spotify:track:6jYiHr12NVKLzn0X7K8aSK    Hearts2Hearts
# 4  spotify:track:4eCan7Jb3q0xQ1FAELOtEz   ALLDAY PROJECT
# 5  spotify:track:4oE7MyJhqSD3BaHRpNs8Nl    Kenshi Yonezu
# ...

# %%
try:
    print(sp.audio_features(["27xkOIER6uDLKALIelHylZ"]))
except Exception as e:
    print(type(e), e)
    
# 오디오 피처 못가져옴 (권한 없음)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=27xkOIER6uDLKALIelHylZ with Params: {} returned 403 due to None
# <class 'spotipy.exceptions.SpotifyException'> http status: 403, code: -1 - https://api.spotify.com/v1/audio-features/?ids=27xkOIER6uDLKALIelHylZ:
#  None, reason: None
